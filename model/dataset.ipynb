# %%
import json
import pandas as pd
from sklearn.model_selection import train_test_split
import json
import torch

# %%
def read_data(data_dir):
    with open(data_dir, 'r', encoding = 'utf-8') as f:
        data = json.load(f)
    return data

# %%
dataset = read_data('Dataset/UIT-ViQuAD.json')
contexts = []
questions = []
answers = []
ids = []
for data in dataset['data']:
    for para in data['paragraphs']:
        context = para['context']
        for qa in para['qas']:
            question = qa['question']
            for answer in qa['answers']:
                contexts.append(context)
                questions.append(question)
                answers.append({'answer_start': [answer['answer_start']], 'text': [answer['text']]})
                ids.append(qa['id'])
icqa = [ids, contexts, questions, answers] 
icqa

# %%
df = pd.DataFrame(list(zip(ids, contexts, questions, answers)),
               columns =['ids', 'contexts', 'questions', 'answers'])
df
# Out:
#               ids                                           contexts  \
# 0      uit_000001  Phạm Văn Đồng (1 tháng 3 năm 1906 – 29 tháng 4...
# 1      uit_000002  Phạm Văn Đồng (1 tháng 3 năm 1906 – 29 tháng 4...
# 2      uit_000003  Phạm Văn Đồng (1 tháng 3 năm 1906 – 29 tháng 4...
# 3      uit_000007  Phạm Văn Đồng (1 tháng 3 năm 1906 – 29 tháng 4...
# 4      uit_000008  Năm 1954, ông được giao nhiệm vụ Trưởng phái đ...
# ...           ...                                                ...
# 19235  uit_028451  Năm 1958, Cộng đồng Pháp khai sinh và Liên hiệ...
# 19236  uit_028452  Năm 1958, Cộng đồng Pháp khai sinh và Liên hiệ...
# 19237  uit_028453  Năm 1958, Cộng đồng Pháp khai sinh và Liên hiệ...
# 19238  uit_028454  Năm 1958, Cộng đồng Pháp khai sinh và Liên hiệ...
# 19239  uit_028455  Năm 1958, Cộng đồng Pháp khai sinh và Liên hiệ...
#
#                                                questions  \
# 0      Tên gọi nào được Phạm Văn Đồng sử dụng khi làm...
# 1      Phạm Văn Đồng giữ chức vụ gì trong bộ máy Nhà ...
# 2      Giai đoạn năm 1955-1976, Phạm Văn Đồng nắm giữ...
# 3      Chủ tịch Hội đồng Bộ trưởng đầu tiên của nước ...
# 4      Sự kiện quan trọng nào đã diễn ra vào ngày 20/...
# ...                                                  ...
# 19235  Điều 86 Hiến pháp Pháp (năm 1958) quy định nhữ...
# 19236  Chính phủ các quốc gia từng là thuộc địa của P...
# 19237  Thời kì Liên hiệp Pháp lãnh đạo kết thúc vào t...
# 19238  Các nước nào đã ký kết hiệp ước với Pháp để tu...
# 19239  Quốc gia nào tiếp tục sử dụng biện pháp bạo lự...
#
#                                                  answers
# 0       {'answer_start': [507], 'text': ['Lâm Bá Kiệt']}
# 1          {'answer_start': [60], 'text': ['Thủ tướng']}
# 2      {'answer_start': [245], 'text': ['Thủ tướng Ch...
# 3       {'answer_start': [0], 'text': ['Phạm Văn Đồng']}
# 4      {'answer_start': [364], 'text': ['bản Hiệp địn...
# ...                                                  ...
# 19235  {'answer_start': [114], 'text': ['mỗi quốc gia...
# 19236  {'answer_start': [467], 'text': ['tiếp tục đàm...
# 19237        {'answer_start': [0], 'text': ['Năm 1958']}
# 19238  {'answer_start': [570], 'text': ['Algérie, Tun...
# 19239       {'answer_start': [288], 'text': ['Algérie']}
#
# [19240 rows x 4 columns]

# %%
from transformers import BertForQuestionAnswering

model = BertForQuestionAnswering.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')

# %% [markdown]
# from transformers import BertTokenizer
#
# tokenizer = BertTokenizer.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
